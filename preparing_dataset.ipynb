# %%
import wbgapi as wb
import pandas as pd

# %%
def read_data(codes):
    worldbank_data = wb.data.DataFrame(codes, 
                                       ['DEU', 'AUS', 'CAN', 'USA', 'FRA', 'ITA', 'JPN', 'GBR', 'ZAF', 'SAU', 'ARG', 'BRA', 'CHN', 'KOR', 'IND', 'IDN', 'MEX', 'RUS', 'TUR'],
                                      range(1990, 2020, 1))
    return worldbank_data

# %% [markdown]
# ## Agricultura e desenvolvimento rural

# %%
inputs_agricultura= ['NV.AGR.TOTL.CD']

# %%
df_inputs_agricultura = read_data(inputs_agricultura)

# %%
df_inputs_agricultura[df_inputs_agricultura.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_inputs_agricultura.fillna(df_inputs_agricultura.mean(), inplace=True)
# df_inputs_agricultura = df_inputs_agricultura.groupby(level=0).sum()
# Out:
#                YR1990        YR1991        YR1992        YR1993        YR1994  \
# economy
# ARG      1.148301e+10  1.274253e+10  1.370624e+10  1.216101e+10  1.308482e+10
# AUS      1.308119e+10  1.035241e+10  9.920018e+09  1.016793e+10  1.079142e+10
# BRA      3.175134e+10  4.092700e+10  2.716044e+10  2.873521e+10  4.764273e+10
# CAN      3.399315e+10  3.194693e+10  2.952908e+10  2.866909e+10  3.559099e+10
# CHN      9.593158e+10  9.214020e+10  9.105626e+10  8.586635e+10  1.098982e+11
# DEU      3.399315e+10  2.058692e+10  2.143143e+10  1.991719e+10  2.151139e+10
# FRA      3.981207e+10  3.318335e+10  3.633705e+10  3.036831e+10  3.346526e+10
# GBR      1.425864e+10  1.462241e+10  1.496983e+10  1.358868e+10  1.509451e+10
# IDN      2.287197e+10  2.292999e+10  2.499267e+10  2.825135e+10  3.057804e+10
# IND      8.633193e+10  7.382848e+10  7.686453e+10  7.507980e+10  8.636351e+10
# ITA      3.759086e+10  4.036742e+10  4.116146e+10  3.193349e+10  3.288418e+10
# JPN      3.399315e+10  3.194693e+10  2.952908e+10  2.866909e+10  9.458280e+10
# KOR      2.155434e+10  2.256508e+10  2.349171e+10  2.322573e+10  2.623250e+10
# MEX      1.741803e+10  2.034485e+10  2.178575e+10  2.554004e+10  2.436840e+10
# RUS      7.990485e+10  7.133333e+10  3.343258e+10  3.288016e+10  2.413749e+10
# SAU      6.713485e+09  7.183445e+09  7.686248e+09  8.070494e+09  8.312684e+09
# TUR      2.633253e+10  2.287486e+10  2.374299e+10  2.777500e+10  2.020841e+10
# USA      3.399315e+10  3.194693e+10  2.952908e+10  2.866909e+10  3.559099e+10
# ZAF      4.861399e+09  5.168580e+09  4.726157e+09  5.144597e+09  5.890504e+09
#
#                YR1995        YR1996        YR1997        YR1998        YR1999  \
# economy
# ARG      1.380848e+10  1.526996e+10  1.529302e+10  1.570292e+10  1.263896e+10
# AUS      1.109593e+10  1.357891e+10  1.409454e+10  1.212236e+10  1.189685e+10
# BRA      3.855502e+10  4.055183e+10  4.137832e+10  4.102725e+10  2.784748e+10
# CAN      3.831539e+10  4.091599e+10  1.401343e+10  1.374115e+10  1.489937e+10
# CHN      1.439458e+11  1.669232e+11  1.720817e+11  1.765739e+11  1.757483e+11
# DEU      2.574041e+10  2.602547e+10  2.281412e+10  2.183728e+10  2.102919e+10
# FRA      3.914312e+10  3.860495e+10  3.405934e+10  3.551034e+10  3.337950e+10
# GBR      1.698438e+10  1.559282e+10  1.516208e+10  1.600696e+10  1.482770e+10
# IDN      3.464209e+10  3.790795e+10  3.471857e+10  1.725928e+10  2.745801e+10
# IND      8.811364e+10  9.986277e+10  1.012445e+11  1.027205e+11  1.054780e+11
# ITA      3.497801e+10  3.903928e+10  3.554150e+10  3.516594e+10  3.408300e+10
# JPN      9.122620e+10  8.140994e+10  6.864070e+10  6.570857e+10  7.306587e+10
# KOR      3.019137e+10  3.026838e+10  2.549748e+10  1.619934e+10  2.114307e+10
# MEX      1.593280e+10  2.000821e+10  2.226983e+10  2.189566e+10  2.209497e+10
# RUS      2.647026e+10  2.565553e+10  2.376837e+10  1.382792e+10  1.289196e+10
# SAU      8.437383e+09  8.587984e+09  8.918621e+09  9.040267e+09  9.184800e+09
# TUR      2.659777e+10  3.058690e+10  2.745228e+10  3.435881e+10  2.681235e+10
# USA      3.831539e+10  4.091599e+10  1.146743e+11  1.100223e+11  1.108665e+11
# ZAF      5.498883e+09  5.697672e+09  5.634332e+09  4.750647e+09  4.424094e+09
#
#          ...        YR2010        YR2011        YR2012        YR2013  \
# economy  ...
# ARG      ...  3.021382e+10  3.710472e+10  3.156730e+10  3.341363e+10
# AUS      ...  2.518718e+10  3.179533e+10  3.486183e+10  3.591977e+10
# BRA      ...  9.091178e+10  1.135964e+11  1.027572e+11  1.114471e+11
# CAN      ...  2.415075e+10  3.166413e+10  3.311804e+10  3.497883e+10
# CHN      ...  5.676388e+11  6.930505e+11  7.776030e+11  8.558713e+11
# DEU      ...  2.729639e+10  3.407496e+10  2.990902e+10  3.518645e+10
# FRA      ...  4.238820e+10  4.722145e+10  4.379453e+10  4.100328e+10
# GBR      ...  1.506847e+10  1.853908e+10  1.740787e+10  1.794389e+10
# IDN      ...  1.051787e+11  1.206605e+11  1.227557e+11  1.218831e+11
# IND      ...  2.852988e+11  3.134183e+11  3.078725e+11  3.183986e+11
# ITA      ...  3.788980e+10  4.316796e+10  4.113114e+10  4.592243e+10
# JPN      ...  6.382670e+10  6.733493e+10  7.042948e+10  5.560083e+10
# KOR      ...  2.452898e+10  2.768620e+10  2.794879e+10  2.877364e+10
# MEX      ...  3.405226e+10  3.645897e+10  3.812169e+10  4.000201e+10
# RUS      ...  5.099169e+10  6.446150e+10  6.461542e+10  6.862749e+10
# SAU      ...  1.394613e+10  1.457547e+10  1.530347e+10  1.610747e+10
# TUR      ...  6.967237e+10  6.856010e+10  6.775774e+10  6.394263e+10
# USA      ...  1.562894e+11  1.890736e+11  1.876956e+11  2.238283e+11
# ZAF      ...  8.960991e+09  9.517139e+09  8.598350e+09  7.695187e+09
#
#                YR2014        YR2015        YR2016        YR2017        YR2018  \
# economy
# ARG      3.533028e+10  3.066935e+10  3.492692e+10  3.367222e+10  2.741595e+10
# AUS      3.252272e+10  3.207089e+10  2.905008e+10  3.594690e+10  3.522518e+10
# BRA      1.062367e+11  7.784003e+10  8.783404e+10  9.493357e+10  8.473671e+10
# CAN      2.864909e+10  2.910416e+10  2.845471e+10  3.117103e+10  1.256518e+11
# CHN      9.054648e+11  9.277341e+11  9.050974e+11  9.187954e+11  9.786148e+11
# DEU      3.513191e+10  2.297986e+10  2.421809e+10  3.135912e+10  2.739067e+10
# FRA      4.438986e+10  3.914895e+10  3.551521e+10  3.992912e+10  4.599696e+10
# GBR      2.314352e+10  1.898875e+10  1.551778e+10  1.527279e+10  1.625573e+10
# IDN      1.188058e+11  1.161520e+11  1.256054e+11  1.336212e+11  1.334993e+11
# IND      3.424089e+11  3.402450e+11  3.755162e+11  4.390397e+11  4.313718e+11
# ITA      4.313649e+10  3.791567e+10  3.617238e+10  3.860446e+10  4.067700e+10
# JPN      4.880373e+10  4.596592e+10  5.629044e+10  5.564157e+10  5.272081e+10
# KOR      3.052763e+10  2.937274e+10  2.788760e+10  3.005446e+10  3.012276e+10
# MEX      4.119798e+10  3.740512e+10  3.609131e+10  3.918371e+10  4.123953e+10
# RUS      6.920300e+10  5.280905e+10  4.903139e+10  5.594125e+10  5.625397e+10
# SAU      1.684373e+10  1.713787e+10  1.732060e+10  1.741071e+10  1.749576e+10
# TUR      6.156933e+10  5.936451e+10  5.341908e+10  5.187160e+10  4.495744e+10
# USA      2.077970e+11  1.903835e+11  1.769514e+11  1.856204e+11  1.897446e+11
# ZAF      7.631146e+09  6.634302e+09  6.591156e+09  8.253799e+09  8.014040e+09
#
#                YR2019
# economy
# ARG      2.712047e+10
# AUS      2.962952e+10
# BRA      8.265677e+10
# CAN      1.309768e+11
# CHN      1.020115e+12
# DEU      3.028962e+10
# FRA      4.154594e+10
# GBR      1.665337e+10
# IDN      1.422667e+11
# IND      4.787272e+11
# ITA      3.827629e+10
# JPN      5.185137e+10
# KOR      2.671704e+10
# MEX      4.299388e+10
# RUS      5.898589e+10
# SAU      1.770962e+10
# TUR      4.890812e+10
# USA      1.965138e+11
# ZAF      6.622879e+09
#
# [19 rows x 30 columns]

# %%
outputs_agricultura = ['SL.AGR.EMPL.ZS','SP.RUR.TOTL.ZS','AG.PRD.FOOD.XD']

# %%
df_outputs_agricultura = read_data(outputs_agricultura)

# %%
df_outputs_agricultura[df_outputs_agricultura.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_agricultura.fillna(df_outputs_agricultura.mean(), inplace=True)
# df_outputs_agricultura = df_outputs_agricultura.groupby(level=0).sum()

# %% [markdown]
# ## Educação

# %%
inputs_educacao=["SE.XPD.PRIM.ZS", "SE.XPD.SECO.ZS", "SE.XPD.TERT.ZS", "SE.XPD.TOTL.GB.ZS"]

# %%
df_inputs_educacao = read_data(inputs_educacao)

# %%
df_inputs_educacao[df_inputs_educacao.isnull().all(axis=1)]
# Out:
#                            YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  \
# economy series
# CAN     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# KOR     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# RUS     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# SAU     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR1996  YR1997  YR1998  YR1999  ...  YR2010  \
# economy series                                             ...
# CAN     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN  ...     NaN
# KOR     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN  ...     NaN
# RUS     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN  ...     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN  ...     NaN
# SAU     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN  ...     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN  ...     NaN
# USA     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN  ...     NaN
#
#                            YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy series
# CAN     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# KOR     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# RUS     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# SAU     SE.XPD.PRIM.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR2017  YR2018  YR2019
# economy series
# CAN     SE.XPD.PRIM.ZS        NaN     NaN     NaN
# KOR     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN
# RUS     SE.XPD.PRIM.ZS        NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN
# SAU     SE.XPD.PRIM.ZS        NaN     NaN     NaN
#         SE.XPD.SECO.ZS        NaN     NaN     NaN
# USA     SE.XPD.TOTL.GB.ZS     NaN     NaN     NaN
#
# [7 rows x 30 columns]

# %%
df_inputs_educacao.fillna(df_inputs_educacao.mean(), inplace=True)
# df_inputs_educacao = df_inputs_educacao.groupby(level=0).sum()

# %%
outputs_educacao = ["SE.ADT.LITR.ZS","SE.ADT.1524.LT.ZS","SE.PRM.CMPT.ZS"]

# %%
df_outputs_educacao = read_data(outputs_educacao)

# %%
df_outputs_educacao[df_outputs_educacao.isnull().all(axis=1)]
# Out:
#                            YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  \
# economy series
# AUS     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.PRM.CMPT.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# CAN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# DEU     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# FRA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# GBR     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# JPN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR1996  YR1997  YR1998  YR1999  ...  YR2010  \
# economy series                                             ...
# AUS     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
#         SE.PRM.CMPT.ZS        NaN     NaN     NaN     NaN  ...     NaN
# CAN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
# DEU     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
# FRA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
# GBR     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
# JPN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
# USA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN  ...     NaN
#
#                            YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy series
# AUS     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#         SE.PRM.CMPT.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# CAN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# DEU     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# FRA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# GBR     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# JPN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR2017  YR2018  YR2019
# economy series
# AUS     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
#         SE.PRM.CMPT.ZS        NaN     NaN     NaN
# CAN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
# DEU     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
# FRA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
# GBR     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
# JPN     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
# USA     SE.ADT.1524.LT.ZS     NaN     NaN     NaN
#         SE.ADT.LITR.ZS        NaN     NaN     NaN
#
# [15 rows x 30 columns]

# %%
df_outputs_educacao.fillna(df_outputs_educacao.mean(), inplace=True)
# df_outputs_educacao = df_outputs_educacao.groupby(level=0).sum()

# %%
ouputs_negative_educacao=['SE.SEC.CMPT.LO.ZS','SE.SEC.UNER.LO.ZS','SE.SEC.CMPT.LO.ZS']
df_ouputs_negative_educacao = read_data(ouputs_negative_educacao)

# %%
df_ouputs_negative_educacao[df_ouputs_negative_educacao.isnull().all(axis=1)]
# Out:
#                            YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  \
# economy series
# AUS     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# CAN     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# CHN     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR1996  YR1997  YR1998  YR1999  ...  YR2010  \
# economy series                                             ...
# AUS     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN  ...     NaN
# CAN     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN  ...     NaN
# CHN     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN  ...     NaN
# USA     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN  ...     NaN
#
#                            YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy series
# AUS     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# CAN     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# CHN     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# USA     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR2017  YR2018  YR2019
# economy series
# AUS     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN
# CAN     SE.SEC.CMPT.LO.ZS     NaN     NaN     NaN
# CHN     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN
# USA     SE.SEC.UNER.LO.ZS     NaN     NaN     NaN
#
# [4 rows x 30 columns]

# %%
df_ouputs_negative_educacao.fillna(df_ouputs_negative_educacao.mean(), inplace=True)
# df_ouputs_negative_educacao = df_ouputs_negative_educacao.groupby(level=0).sum()

# %% [markdown]
# ## Mudanças climáticas e meio ambiente

# %%
inputs_ambiente = ['EN.ATM.METH.AG.ZS','EN.ATM.METH.AG.KT.CE','EN.ATM.NOXE.AG.ZS','EN.ATM.CO2E.KD.GD']

# %%
df_inputs_ambiente = read_data(inputs_ambiente)

# %%
df_inputs_ambiente[df_inputs_ambiente.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_inputs_ambiente.fillna(df_inputs_ambiente.mean(), inplace=True)
# df_inputs_ambiente = df_inputs_ambiente.groupby(level=0).sum()

# %%
outputs_ambiente = ["EG.ELC.ACCS.ZS","EG.ELC.HYRO.ZS","EG.ELC.RNWX.ZS"]

# %%
df_outputs_ambiente = read_data(inputs_ambiente)

# %%
df_outputs_ambiente[df_outputs_ambiente.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_ambiente.fillna(df_outputs_ambiente.mean(), inplace=True)
# df_outputs_ambiente = df_outputs_ambiente.groupby(level=0).sum()

# %% [markdown]
# ## Saúde

# %%
inputs_saude = ['SH.XPD.CHEX.GD.ZS','SH.XPD.GHED.CH.ZS']

# %%
df_inputs_saude = read_data(inputs_saude)

# %%
df_inputs_saude[df_inputs_saude.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_inputs_saude.fillna(df_inputs_saude.mean(), inplace=True)
# df_inputs_saude = df_inputs_saude.groupby(level=0).sum()

# %%
outputs_saude = ['SH.STA.BASS.ZS','SH.MED.BEDS.ZS','SH.MED.NUMW.P3','SH.MED.PHYS.ZS']

# %%
df_outputs_saude = read_data(outputs_saude)

# %%
df_outputs_saude[df_outputs_saude.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_saude.fillna(df_outputs_saude.mean(), inplace=True)
# df_outputs_saude = df_outputs_saude.groupby(level=0).sum()

# %% [markdown]
# ## Infraestreutura, Ciência e Tecnologia

# %%
inputs_ciencia = ['GB.XPD.RSDV.GD.ZS']

# %%
df_inputs_ciencia = read_data(inputs_ciencia)

# %%
df_inputs_ciencia[df_inputs_ciencia.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_inputs_ciencia.fillna(df_inputs_ciencia.mean(), inplace=True)
# df_inputs_ciencia = df_inputs_ciencia.groupby(level=0).sum()

# %%
outputs_ciencia =['IT.NET.SECR.P6','EP.PMP.SGAS.CD','IP.JRN.ARTC.SC','IP.IDS.NRCT','IP.IDS.RSCT','IS.RRS.GOOD.MT.K6']

# %%
df_outputs_ciencia = read_data(outputs_ciencia)

# %%
df_outputs_ciencia[df_outputs_ciencia.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_ciencia.fillna(df_outputs_ciencia.mean(), inplace=True)
# df_outputs_ciencia = df_outputs_ciencia.groupby(level=0).sum()

# %% [markdown]
# ## Desenvolvimento

# %%
inputs_desenvolvimento = ['SI.POV.GINI']

# %%
df_inputs_desenvolvimento = read_data(inputs_desenvolvimento)

# %%
df_inputs_desenvolvimento[df_inputs_desenvolvimento.isnull().all(axis=1)]
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# SAU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  \
# economy                  ...
# SAU         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2016  YR2017  YR2018  YR2019
# economy
# SAU         NaN     NaN     NaN     NaN
#
# [1 rows x 30 columns]

# %%
df_inputs_desenvolvimento.fillna(df_inputs_desenvolvimento.mean(), inplace=True)
# df_inputs_desenvolvimento = df_inputs_desenvolvimento.groupby(level=0).sum()

# %%
outputs_desenvolvimento = ['SL.EMP.VULN.ZS','SL.UEM.TOTL.NE.ZS']

# %%
df_outputs_desenvolvimento = read_data(outputs_desenvolvimento)

# %%
df_outputs_desenvolvimento[df_outputs_desenvolvimento.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_desenvolvimento.fillna(df_outputs_desenvolvimento.mean(), inplace=True)
# df_outputs_desenvolvimento = df_outputs_desenvolvimento.groupby(level=0).sum()

# %%
ouputs_negative_desenvolvimento = ['SI.DST.50MD']
df_ouputs_negative_desenvolvimento = read_data(ouputs_negative_desenvolvimento)

# %%
df_ouputs_negative_desenvolvimento[df_ouputs_negative_desenvolvimento.isnull().all(axis=1)]
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# CHN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IDN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# SAU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  \
# economy                  ...
# CHN         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# IDN         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# SAU         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2016  YR2017  YR2018  YR2019
# economy
# CHN         NaN     NaN     NaN     NaN
# IDN         NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN
# SAU         NaN     NaN     NaN     NaN
#
# [4 rows x 30 columns]

# %%
df_ouputs_negative_desenvolvimento.fillna(df_ouputs_negative_desenvolvimento.mean(), inplace=True)
# df_ouputs_negative_desenvolvimento = df_ouputs_negative_desenvolvimento.groupby(level=0).sum()
df_ouputs_negative_desenvolvimento * -1
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994     YR1995     YR1996  YR1997  \
# economy
# ARG       -25.9   -17.2 -19.600  -20.10   -20.7 -21.200000 -22.500000  -22.20
# AUS       -25.9   -13.3 -20.925  -21.15   -15.0 -10.400000 -22.183333  -18.66
# BRA       -25.9   -13.3 -25.300  -25.10   -15.0 -24.200000 -26.200000  -25.30
# CAN       -25.9   -11.2 -20.925  -21.15   -11.7 -16.171429 -22.183333  -13.00
# CHN       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# DEU       -25.9    -7.2 -20.925  -21.15    -8.7  -9.000000 -22.183333  -18.66
# FRA       -25.9   -13.3 -20.925  -21.15   -10.2 -16.171429 -22.183333  -18.66
# GBR       -25.9   -13.5 -20.925  -21.15   -13.2 -15.000000 -22.183333  -18.66
# IDN       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# IND       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# ITA       -25.9   -12.0 -20.925  -16.70   -15.0 -15.700000 -22.183333  -18.66
# JPN       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# KOR       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# MEX       -25.9   -13.3 -20.100  -21.15   -20.5 -16.171429 -22.400000  -18.66
# RUS       -25.9   -13.3 -20.925  -20.50   -15.0 -16.171429 -20.700000  -15.10
# SAU       -25.9   -13.3 -20.925  -21.15   -15.0 -16.171429 -22.183333  -18.66
# TUR       -25.9   -13.3 -20.925  -21.15   -16.8 -16.171429 -22.183333  -18.66
# USA       -25.9   -18.7 -18.700  -19.00   -18.2 -17.700000 -18.000000  -17.70
# ZAF       -25.9   -13.3 -20.925  -25.50   -15.0 -16.171429 -23.300000  -18.66
#
#           YR1998  YR1999  ...     YR2010  YR2011     YR2012     YR2013  \
# economy                   ...
# ARG     -23.0000  -22.80  ... -21.600000   -20.7 -20.200000 -20.200000
# AUS     -17.5125  -19.12  ... -10.300000   -15.1 -15.091667 -14.618182
# BRA     -25.0000  -25.10  ... -14.328571   -23.0 -22.800000 -22.600000
# CAN     -13.2000  -19.12  ... -13.200000   -15.1 -14.200000 -14.700000
# CHN     -17.5125  -19.12  ... -14.328571   -15.1 -15.091667 -14.618182
# DEU      -7.7000  -19.12  ...  -9.000000    -8.7  -9.700000  -9.700000
# FRA     -17.5125  -19.12  ... -10.300000    -9.9 -10.100000  -9.800000
# GBR     -17.5125  -14.50  ... -11.600000   -12.1 -11.900000 -13.100000
# IDN     -17.5125  -19.12  ... -14.328571   -15.1 -15.091667 -14.618182
# IND     -17.5125  -19.12  ... -14.328571   -15.1 -15.091667 -14.618182
# ITA     -15.7000  -19.12  ... -14.500000   -14.7 -14.200000 -14.800000
# JPN     -17.5125  -19.12  ...  -8.700000   -15.1 -15.091667  -9.100000
# KOR     -17.5125  -19.12  ... -12.500000   -15.1 -13.000000 -14.618182
# MEX     -22.0000  -19.12  ... -17.700000   -15.1 -18.100000 -14.618182
# RUS     -15.5000  -15.50  ... -13.200000   -12.9 -12.700000 -12.500000
# SAU     -17.5125  -19.12  ... -14.328571   -15.1 -15.091667 -14.618182
# TUR     -17.5125  -19.12  ... -16.500000   -15.9 -16.000000 -16.300000
# USA     -18.0000  -17.70  ... -18.000000   -18.0 -18.200000 -18.000000
# ZAF     -17.5125  -19.12  ... -23.500000   -15.1 -15.091667 -14.618182
#
#          YR2014     YR2015  YR2016     YR2017     YR2018     YR2019
# economy
# ARG      -20.20 -14.411111 -20.700 -19.500000 -20.300000 -21.300000
# AUS      -10.00 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# BRA      -22.20 -22.400000 -23.000 -23.100000 -23.600000 -23.900000
# CAN      -13.70 -13.700000 -12.700 -13.200000 -16.257143 -20.833333
# CHN      -15.15 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# DEU      -10.50 -11.000000 -11.700 -15.666667 -16.257143 -20.833333
# FRA      -10.10 -10.800000 -10.400 -10.100000 -10.000000 -20.833333
# GBR      -13.10 -11.300000 -12.700 -14.000000 -16.257143 -20.833333
# IDN      -15.15 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# IND      -15.15 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# ITA      -15.20 -16.100000 -15.700 -16.000000 -16.257143 -20.833333
# JPN      -15.15 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# KOR      -12.50 -14.411111 -12.200 -15.666667 -16.257143 -20.833333
# MEX      -16.40 -14.411111 -16.000 -15.666667 -15.300000 -20.833333
# RUS      -12.00 -11.600000 -11.800 -11.300000 -10.800000 -20.833333
# SAU      -15.15 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
# TUR      -15.70 -15.600000 -16.000 -15.600000 -15.600000 -17.300000
# USA      -17.00 -17.200000 -18.000 -18.200000 -18.200000 -20.833333
# ZAF      -23.50 -14.411111 -15.075 -15.666667 -16.257143 -20.833333
#
# [19 rows x 30 columns]

# %% [markdown]
# ## Banco Central

# %%
inputs_banco = ['FR.INR.DPST']

# %%
df_inputs_banco= read_data(inputs_banco)

# %%
df_inputs_banco[df_inputs_banco.isnull().all(axis=1)]
# Out:
#          YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  YR1996  YR1997  \
# economy
# DEU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ITA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# SAU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# USA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1998  YR1999  ...  YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  \
# economy                  ...
# DEU         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ITA         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# SAU         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# USA         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2016  YR2017  YR2018  YR2019
# economy
# DEU         NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN
# ITA         NaN     NaN     NaN     NaN
# SAU         NaN     NaN     NaN     NaN
# USA         NaN     NaN     NaN     NaN
#
# [5 rows x 30 columns]

# %%
df_inputs_banco.fillna(df_inputs_banco.mean(), inplace=True)
# df_inputs_banco=df_inputs_banco.groupby(level=0).sum()

# %%
outputs_banco = ['FM.LBL.BMNY.GD.ZS','FM.LBL.BMNY.ZG','FP.CPI.TOTL.ZG','NY.GDP.DEFL.KD.ZG.AD','PA.NUS.FCRF']

# %%
df_outputs_banco = read_data(outputs_banco)

# %%
df_outputs_banco[df_outputs_banco.isnull().all(axis=1)]
# Out:
#                            YR1990  YR1991  YR1992  YR1993  YR1994  YR1995  \
# economy series
# ARG     FP.CPI.TOTL.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# DEU     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# FRA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# ITA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR1996  YR1997  YR1998  YR1999  ...  YR2010  \
# economy series                                             ...
# ARG     FP.CPI.TOTL.ZG        NaN     NaN     NaN     NaN  ...     NaN
# DEU     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN  ...     NaN
# FRA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN  ...     NaN
# ITA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN  ...     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN  ...     NaN
#
#                            YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# economy series
# ARG     FP.CPI.TOTL.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# DEU     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# FRA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
# ITA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN     NaN     NaN     NaN
#
#                            YR2017  YR2018  YR2019
# economy series
# ARG     FP.CPI.TOTL.ZG        NaN     NaN     NaN
# DEU     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN
# FRA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN
# ITA     FM.LBL.BMNY.GD.ZS     NaN     NaN     NaN
#         FM.LBL.BMNY.ZG        NaN     NaN     NaN
#
# [7 rows x 30 columns]

# %%
df_outputs_banco.fillna(df_outputs_banco.mean(), inplace=True)
# df_outputs_banco=df_outputs_banco.groupby(level=0).sum()

# %% [markdown]
# ## Economia

# %%
# inputs_economia =['NY.GDP.FCST.CD','NV.IND.TOTL.CD','NV.IND.MANF.CD','NV.SRV.TOTL.CD']
inputs_economia =['NY.GDP.FCST.CD']

# %%
df_inputs_economia = read_data(inputs_economia)

# %%
# df_inputs_economia[df_inputs_economia.isnull().all(axis=1)]
df_inputs_economia=df_inputs_economia.fillna(df_inputs_economia.mean(), inplace=True)
df_inputs_economia.transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_46101/1119160442.py in <module>
#       1 # df_inputs_economia[df_inputs_economia.isnull().all(axis=1)]
# ----> 2 df_inputs_economia=df_inputs_economia.fillna(df_inputs_economia.mean(), inplace=True)
#       3 df_inputs_economia.transpose()
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
df_inputs_economia.fillna(df_inputs_economia.mean(), inplace=True)
# df_inputs_economia.groupby(level=0).sum()

# %%
df_inputs_economia
# Out:
#                YR1990        YR1991        YR1992        YR1993        YR1994  \
# economy
# ARG      1.413524e+11  1.897200e+11  2.287886e+11  2.180159e+11  2.373060e+11
# AUS      2.873205e+11  2.994726e+11  2.982035e+11  2.885392e+11  2.984351e+11
# BRA      3.919918e+11  5.253800e+11  3.518192e+11  3.800954e+11  4.836696e+11
# CAN      5.511990e+11  5.655407e+11  5.482336e+11  5.342439e+11  5.361702e+11
# CHN      9.695414e+11  1.033470e+12  1.094491e+12  1.127664e+12  1.203074e+12
# DEU      1.615985e+12  1.700643e+12  1.937699e+12  1.879097e+12  1.990646e+12
# FRA      1.137035e+12  1.138964e+12  1.263817e+12  1.193098e+12  1.248946e+12
# GBR      9.679640e+11  1.006373e+12  1.044702e+12  9.430564e+11  1.019226e+12
# IDN      9.695414e+11  1.033470e+12  1.094491e+12  1.127664e+12  1.203074e+12
# IND      2.896022e+11  2.445733e+11  2.604250e+11  2.548987e+11  2.974073e+11
# ITA      1.079131e+12  1.131978e+12  1.196117e+12  9.684336e+11  9.988751e+11
# JPN      3.112762e+12  3.562464e+12  3.890035e+12  4.459258e+12  4.891224e+12
# KOR      2.562061e+11  3.012898e+11  3.235186e+11  3.583128e+11  4.221518e+11
# MEX      2.389249e+11  2.863433e+11  3.320465e+11  4.787289e+11  5.025947e+11
# RUS      4.810336e+11  4.990370e+11  4.521864e+11  3.956180e+11  3.640932e+11
# SAU      1.157611e+11  1.303541e+11  1.346580e+11  1.304907e+11  1.329615e+11
# TUR      1.455407e+11  1.447407e+11  1.525587e+11  1.727853e+11  1.260992e+11
# USA      5.565148e+12  5.728527e+12  6.067042e+12  6.392114e+12  6.774514e+12
# ZAF      1.052463e+11  1.135958e+11  1.244923e+11  1.235098e+11  1.279317e+11
#
#                YR1995        YR1996        YR1997        YR1998        YR1999  \
# economy
# ARG      2.386122e+11  2.510996e+11  2.695580e+11  2.753496e+11  2.624742e+11
# AUS      3.373225e+11  3.675736e+11  3.992409e+11  3.670121e+11  3.576513e+11
# BRA      6.655610e+11  7.435058e+11  7.761992e+11  7.599680e+11  5.190486e+11
# CAN      5.600590e+11  5.835497e+11  6.048714e+11  5.847995e+11  6.261453e+11
# CHN      1.316912e+12  1.328414e+12  1.340025e+12  1.338748e+12  1.324616e+12
# DEU      2.342734e+12  2.263657e+12  2.006624e+12  2.029410e+12  1.978073e+12
# FRA      1.433434e+12  1.432058e+12  1.296970e+12  1.342191e+12  1.333345e+12
# GBR      1.216397e+12  1.285381e+12  1.409262e+12  1.486694e+12  1.509191e+12
# IDN      1.316912e+12  1.328414e+12  1.340025e+12  1.338748e+12  1.400014e+11
# IND      3.267274e+11  3.584040e+11  3.807740e+11  3.877637e+11  4.191151e+11
# ITA      1.061497e+12  1.189220e+12  1.119369e+12  1.139289e+12  1.120795e+12
# JPN      5.410741e+12  4.807901e+12  4.408989e+12  4.036548e+12  4.579876e+12
# KOR      5.160469e+11  5.533456e+11  5.163696e+11  3.516345e+11  4.505772e+11
# MEX      3.451311e+11  3.945191e+11  4.779377e+11  5.001114e+11  5.691130e+11
# RUS      3.696700e+11  3.576947e+11  3.691098e+11  2.462236e+11  1.762510e+11
# SAU      1.413404e+11  1.562926e+11  1.635337e+11  1.441054e+11  1.591479e+11
# TUR      1.632822e+11  1.758418e+11  1.834356e+11  2.541705e+11  2.339805e+11
# USA      7.116657e+12  7.527601e+12  8.258301e+12  8.727890e+12  9.283911e+12
# ZAF      1.422966e+11  1.354004e+11  1.398772e+11  1.255554e+11  1.243871e+11
#
#          ...        YR2010        YR2011        YR2012        YR2013  \
# economy  ...
# ARG      ...  3.553646e+11  4.454609e+11  4.579095e+11  4.635791e+11
# AUS      ...  1.066918e+12  1.305094e+12  1.450597e+12  1.477419e+12
# BRA      ...  1.877467e+12  2.224092e+12  2.096287e+12  2.112036e+12
# CAN      ...  1.509673e+12  1.676219e+12  1.711520e+12  1.729798e+12
# CHN      ...  2.320807e+12  2.529871e+12  2.559901e+12  2.576234e+12
# DEU      ...  3.053704e+12  3.361481e+12  3.168213e+12  3.356373e+12
# FRA      ...  2.381037e+12  2.569778e+12  2.409534e+12  2.522496e+12
# GBR      ...  2.228711e+12  2.373693e+12  2.417219e+12  2.486583e+12
# IDN      ...  7.352433e+11  8.752018e+11  8.980540e+11  8.897924e+11
# IND      ...  1.554725e+12  1.691714e+12  1.691388e+12  1.712864e+12
# ITA      ...  1.919661e+12  2.058614e+12  1.873338e+12  1.927234e+12
# JPN      ...  5.686226e+12  6.126753e+12  6.170675e+12  5.124212e+12
# KOR      ...  1.040634e+12  1.144318e+12  1.168407e+12  1.257848e+12
# MEX      ...  1.014896e+12  1.139854e+12  1.164428e+12  1.224759e+12
# RUS      ...  1.318500e+12  1.766900e+12  1.911027e+12  2.001478e+12
# SAU      ...  5.242956e+11  6.666295e+11  7.302431e+11  7.410007e+11
# TUR      ...  6.837643e+11  7.385948e+11  7.779621e+11  8.399198e+11
# USA      ...  1.448293e+13  1.499808e+13  1.562418e+13  1.617492e+13
# ZAF      ...  3.407721e+11  3.752048e+11  3.572369e+11  3.299018e+11
#
#                YR2014        YR2015        YR2016        YR2017        YR2018  \
# economy
# ARG      4.417435e+11  5.003307e+11  4.707846e+11  5.429888e+11  4.362632e+11
# AUS      1.371906e+12  1.261234e+12  1.123813e+12  1.238750e+12  1.336456e+12
# BRA      2.113359e+12  1.549671e+12  1.552379e+12  1.777253e+12  1.645178e+12
# CAN      1.690660e+12  1.452013e+12  1.422813e+12  1.537410e+12  1.601284e+12
# CHN      2.615944e+12  2.459653e+12  2.506650e+12  2.647414e+12  2.763562e+12
# DEU      3.496465e+12  3.018902e+12  3.122050e+12  3.309344e+12  3.569961e+12
# FRA      2.556921e+12  2.182051e+12  2.208753e+12  2.305764e+12  2.477991e+12
# GBR      2.731789e+12  2.611469e+12  2.400825e+12  2.376959e+12  2.551533e+12
# IDN      8.686093e+11  8.337338e+11  8.985995e+11  9.765158e+11  9.999873e+11
# IND      1.881518e+12  1.920694e+12  2.082121e+12  2.405661e+12  2.454305e+12
# ITA      1.940673e+12  1.650346e+12  1.684397e+12  1.755466e+12  1.875931e+12
# JPN      4.813140e+12  4.364433e+12  4.903350e+12  4.835496e+12  4.936224e+12
# KOR      1.362505e+12  1.344559e+12  1.372834e+12  1.485299e+12  1.577956e+12
# MEX      1.247317e+12  1.104157e+12  1.011069e+12  1.094870e+12  1.154630e+12
# RUS      1.791066e+12  1.224538e+12  1.149446e+12  1.420868e+12  1.481277e+12
# SAU      7.500783e+11  6.473379e+11  6.380390e+11  6.823521e+11  7.813604e+11
# TUR      8.309901e+11  7.621399e+11  7.671701e+11  7.619883e+11  6.977758e+11
# USA      1.688335e+13  1.756185e+13  1.804668e+13  1.883299e+13  1.983795e+13
# ZAF      3.149038e+11  2.842909e+11  2.645735e+11  3.134800e+11  3.280433e+11
#
#                YR2019
# economy
# ARG      3.734241e+11
# AUS      1.306269e+12
# BRA      1.614845e+12
# CAN      1.622884e+12
# CHN      1.550690e+12
# DEU      3.477264e+12
# FRA      2.414831e+12
# GBR      2.526622e+12
# IDN      1.073069e+12
# IND      2.603967e+12
# ITA      1.795342e+12
# JPN      1.550690e+12
# KOR      1.507367e+12
# MEX      1.194607e+12
# RUS      1.514207e+12
# SAU      7.873073e+11
# TUR      6.859501e+11
# USA      1.550690e+12
# ZAF      3.130852e+11
#
# [19 rows x 30 columns]

# %%
outputs_economia = ['NY.GDS.TOTL.CD','NE.RSB.GNFS.CD','NE.CON.TOTL.CD','IC.REG.STRT.BUS.DFRN']
# outputs_economia = ['NY.GDS.TOTL.CD']

# %%
df_outputs_economia = read_data(outputs_economia)
df_outputs_economia
# Out:
#                               YR1990        YR1991        YR1992  \
# economy series
# ARG     NE.CON.TOTL.CD  1.134703e+11  1.589208e+11  1.940864e+11
#         NE.RSB.GNFS.CD  8.096966e+09  3.029890e+09 -3.511003e+09
#         NY.GDS.TOTL.CD  2.788203e+10  3.079917e+10  3.470221e+10
# AUS     NE.CON.TOTL.CD  2.250173e+11  2.452547e+11  2.533246e+11
#         NE.RSB.GNFS.CD -5.989227e+09 -4.316773e+08  8.851803e+08
#         NY.GDS.TOTL.CD  8.576376e+10  8.006122e+10  7.155964e+10
# BRA     NE.CON.TOTL.CD  3.630800e+11  4.790800e+11  3.148000e+11
#         NE.RSB.GNFS.CD  5.720000e+09  4.600000e+09  9.947500e+09
#         NY.GDS.TOTL.CD  9.887178e+10  1.237800e+11  8.579925e+10
# CAN     NE.CON.TOTL.CD  4.676800e+11  4.979689e+11  4.882717e+11
#         NE.RSB.GNFS.CD  9.187521e+08 -3.165750e+09 -2.019525e+09
#         NY.GDS.TOTL.CD  1.262496e+11  1.123593e+11  1.041160e+11
# CHN     NE.CON.TOTL.CD  2.296829e+11  2.373801e+11  2.549339e+11
#         NE.RSB.GNFS.CD  1.066800e+10  1.160100e+10  4.998000e+09
#         NY.GDS.TOTL.CD  1.311750e+11  1.459932e+11  1.719818e+11
# DEU     NE.CON.TOTL.CD  1.336585e+12  1.396387e+12  1.603825e+12
#         NE.RSB.GNFS.CD -3.400093e+09 -9.112552e+09 -1.068879e+10
#         NY.GDS.TOTL.CD  4.350864e+11  4.725586e+11  5.277470e+11
# FRA     NE.CON.TOTL.CD  9.693338e+11  9.736845e+11  1.084321e+12
#         NE.RSB.GNFS.CD -9.957836e+09 -3.984420e+09  9.382900e+09
#         NY.GDS.TOTL.CD  2.998458e+11  2.955924e+11  3.171450e+11
# GBR     NE.CON.TOTL.CD  9.331469e+11  9.934398e+11  1.043977e+12
#         NE.RSB.GNFS.CD -2.029749e+10 -4.364303e+09 -8.494545e+09
#         NY.GDS.TOTL.CD  1.600225e+11  1.493573e+11  1.356828e+11
# IDN     NE.CON.TOTL.CD  7.750842e+10  8.555355e+10  9.263547e+10
#         NE.RSB.GNFS.CD  1.825256e+09  2.172618e+09  4.080850e+09
#         NY.GDS.TOTL.CD  2.863231e+10  3.106844e+10  3.539149e+10
# IND     NE.CON.TOTL.CD  2.515212e+11  2.109436e+11  2.209388e+11
#         NE.RSB.GNFS.CD -4.492297e+09  2.039268e+06 -2.153624e+09
#         NY.GDS.TOTL.CD  6.945785e+10  5.916171e+10  6.726962e+10
# ITA     NE.CON.TOTL.CD  9.142625e+11  9.691189e+11  1.037003e+12
#         NE.RSB.GNFS.CD  2.328492e+09  2.412450e+09  5.896936e+08
#         NY.GDS.TOTL.CD  2.669601e+11  2.771012e+11  2.831590e+11
# JPN     NE.CON.TOTL.CD  2.027329e+12  2.303951e+12  2.558562e+12
#         NE.RSB.GNFS.CD  2.433482e+10  5.370186e+10  8.030079e+10
#         NY.GDS.TOTL.CD  1.105489e+12  1.280469e+12  1.350247e+12
# KOR     NE.CON.TOTL.CD  1.734284e+11  2.019748e+11  2.203842e+11
#         NE.RSB.GNFS.CD -2.158217e+09 -7.512102e+09 -2.185230e+09
#         NY.GDS.TOTL.CD  1.099391e+11  1.286738e+11  1.351411e+11
# MEX     NE.CON.TOTL.CD  2.048164e+11  2.502392e+11  2.972219e+11
#         NE.RSB.GNFS.CD -2.901885e+09 -9.143002e+09 -1.830317e+10
#         NY.GDS.TOTL.CD  5.643721e+10  6.290357e+10  6.593570e+10
# RUS     NE.CON.TOTL.CD  3.599834e+11  3.286741e+11  2.362155e+11
#         NE.RSB.GNFS.CD  1.123160e+09  1.481481e+09  6.475303e+10
#         NY.GDS.TOTL.CD  1.568309e+11  1.892889e+11  2.240751e+11
# SAU     NE.CON.TOTL.CD  8.863954e+10  1.032623e+11  1.013282e+11
#         NE.RSB.GNFS.CD  1.054152e+10  2.535381e+09  4.279306e+09
#         NY.GDS.TOTL.CD  2.899074e+10  2.896098e+10  3.575969e+10
# TUR     NE.CON.TOTL.CD  1.198502e+11  1.245540e+11  1.306629e+11
#         NE.RSB.GNFS.CD -6.347675e+09 -4.191405e+09 -4.679130e+09
#         NY.GDS.TOTL.CD  3.082614e+10  2.547388e+10  2.779625e+10
# USA     NE.CON.TOTL.CD  4.757180e+12  4.948306e+12  5.245942e+12
#         NE.RSB.GNFS.CD -7.785400e+10 -2.861300e+10 -3.473800e+10
#         NY.GDS.TOTL.CD  1.205964e+12  1.209823e+12  1.274385e+12
# ZAF     NE.CON.TOTL.CD  9.233606e+10  9.979575e+10  1.097679e+11
#         NE.RSB.GNFS.CD  6.132599e+09  5.137797e+09  5.274194e+09
#         NY.GDS.TOTL.CD  2.321629e+10  2.414768e+10  2.477735e+10
#
#                               YR1993        YR1994        YR1995  \
# economy series
# ARG     NE.CON.TOTL.CD  1.958241e+11  2.139553e+11  2.113544e+11
#         NE.RSB.GNFS.CD -5.692332e+09 -7.914860e+09 -1.059485e+09
#         NY.GDS.TOTL.CD  4.091763e+10  4.348468e+10  4.667731e+10
# AUS     NE.CON.TOTL.CD  2.404040e+11  2.450446e+11  2.787934e+11
#         NE.RSB.GNFS.CD -9.998595e+08 -1.661017e+09 -7.226017e+09
#         NY.GDS.TOTL.CD  7.114531e+10  7.716915e+10  8.842293e+10
# BRA     NE.CON.TOTL.CD  3.403727e+11  4.297982e+11  6.510967e+11
#         NE.RSB.GNFS.CD  6.160807e+09 -1.564211e+07 -1.482228e+10
#         NY.GDS.TOTL.CD  9.742588e+10  1.283138e+11  1.182087e+11
# CAN     NE.CON.TOTL.CD  4.721386e+11  4.596910e+11  4.695293e+11
#         NE.RSB.GNFS.CD  1.992094e+08  6.794815e+09  1.899300e+10
#         NY.GDS.TOTL.CD  1.050322e+11  1.184483e+11  1.345023e+11
# CHN     NE.CON.TOTL.CD  2.594958e+11  3.283188e+11  4.338407e+11
#         NE.RSB.GNFS.CD -1.179200e+10  7.357000e+09  1.195800e+10
#         NY.GDS.TOTL.CD  1.852355e+11  2.360059e+11  3.007072e+11
# DEU     NE.CON.TOTL.CD  1.574441e+12  1.664963e+12  1.946233e+12
#         NE.RSB.GNFS.CD  1.038684e+09  3.606123e+09  1.051999e+10
#         NY.GDS.TOTL.CD  4.968828e+11  5.401109e+11  6.395592e+11
# FRA     NE.CON.TOTL.CD  1.042069e+12  1.089929e+12  1.247046e+12
#         NE.RSB.GNFS.CD  2.222377e+10  2.083176e+10  2.561309e+10
#         NY.GDS.TOTL.CD  2.807470e+11  3.040536e+11  3.540492e+11
# GBR     NE.CON.TOTL.CD  9.411196e+11  1.006511e+12  1.089110e+12
#         NE.RSB.GNFS.CD -3.896687e+09 -3.104989e+08  3.656304e+09
#         NY.GDS.TOTL.CD  1.202691e+11  1.339788e+11  2.525043e+11
# IDN     NE.CON.TOTL.CD  1.067103e+11  1.199275e+11  1.402920e+11
#         NE.RSB.GNFS.CD  4.718461e+09  2.026750e+09 -2.696967e+09
#         NY.GDS.TOTL.CD  5.129639e+10  5.696467e+10  6.184003e+10
# IND     NE.CON.TOTL.CD  2.135336e+11  2.463621e+11  2.674759e+11
#         NE.RSB.GNFS.CD  4.718741e+07 -9.882890e+08 -4.249571e+09
#         NY.GDS.TOTL.CD  6.576242e+10  8.091348e+10  9.280601e+10
# ITA     NE.CON.TOTL.CD  8.298279e+11  8.543705e+11  8.962346e+11
#         NE.RSB.GNFS.CD  3.236368e+10  3.613288e+10  4.299762e+10
#         NY.GDS.TOTL.CD  2.351302e+11  2.448462e+11  2.784274e+11
# JPN     NE.CON.TOTL.CD  2.992254e+12  3.373096e+12  3.761198e+12
#         NE.RSB.GNFS.CD  9.540027e+10  9.344492e+10  6.892226e+10
#         NY.GDS.TOTL.CD  1.461890e+12  1.625702e+12  1.784365e+12
# KOR     NE.CON.TOTL.CD  2.429181e+11  2.875682e+11  3.512912e+11
#         NE.RSB.GNFS.CD  1.673789e+09 -2.430767e+09 -5.753757e+09
#         NY.GDS.TOTL.CD  1.497480e+11  1.760492e+11  2.152922e+11
# MEX     NE.CON.TOTL.CD  3.930813e+11  4.122201e+11  2.692534e+11
#         NE.RSB.GNFS.CD -1.635061e+10 -2.081830e+10  7.119984e+09
#         NY.GDS.TOTL.CD  1.076548e+11  1.155932e+11  9.082055e+10
# RUS     NE.CON.TOTL.CD  2.840317e+11  2.761571e+11  2.814819e+11
#         NE.RSB.GNFS.CD  3.354820e+10  1.802756e+10  1.342895e+10
#         NY.GDS.TOTL.CD  1.510520e+11  1.189202e+11  1.140553e+11
# SAU     NE.CON.TOTL.CD  9.845794e+10  9.693708e+10  1.004546e+11
#         NE.RSB.GNFS.CD  1.194927e+09  1.072016e+10  1.380961e+10
#         NY.GDS.TOTL.CD  3.450996e+10  3.823780e+10  4.288839e+10
# TUR     NE.CON.TOTL.CD  1.477162e+11  1.066628e+11  1.374486e+11
#         NE.RSB.GNFS.CD -1.021469e+10  1.278686e+09 -7.558090e+09
#         NY.GDS.TOTL.CD  3.245352e+10  2.402735e+10  3.203734e+10
# USA     NE.CON.TOTL.CD  5.525024e+12  5.829066e+12  6.104333e+12
#         NE.RSB.GNFS.CD -6.517400e+10 -9.248700e+10 -8.976200e+10
#         NY.GDS.TOTL.CD  1.333535e+12  1.458170e+12  1.535416e+12
# ZAF     NE.CON.TOTL.CD  1.089684e+11  1.146268e+11  1.256701e+11
#         NE.RSB.GNFS.CD  6.080118e+09  3.045792e+09  1.026440e+09
#         NY.GDS.TOTL.CD  2.534137e+10  2.512561e+10  2.979019e+10
#
#                               YR1996        YR1997        YR1998  \
# economy series
# ARG     NE.CON.TOTL.CD  2.205104e+11  2.383532e+11  2.437867e+11
#         NE.RSB.GNFS.CD -1.767000e+09 -6.485300e+09 -7.530100e+09
#         NY.GDS.TOTL.CD  5.163931e+10  5.450579e+10  5.516154e+10
# AUS     NE.CON.TOTL.CD  3.026396e+11  3.250939e+11  2.999254e+11
#         NE.RSB.GNFS.CD -1.817147e+09  1.194240e+09 -3.507427e+09
#         NY.GDS.TOTL.CD  9.766313e+10  1.094741e+11  9.897375e+10
# BRA     NE.CON.TOTL.CD  7.220820e+11  7.493501e+11  7.273659e+11
#         NE.RSB.GNFS.CD -1.849824e+10 -2.304188e+10 -2.053575e+10
#         NY.GDS.TOTL.CD  1.283444e+11  1.338496e+11  1.363575e+11
# CAN     NE.CON.TOTL.CD  4.867334e+11  5.025704e+11  4.876724e+11
#         NE.RSB.GNFS.CD  2.482582e+10  1.263686e+10  1.253522e+10
#         NY.GDS.TOTL.CD  1.418130e+11  1.524166e+11  1.463276e+11
# CHN     NE.CON.TOTL.CD  5.186580e+11  5.735813e+11  6.220703e+11
#         NE.RSB.GNFS.CD  1.755000e+10  4.282322e+10  4.383669e+10
#         NY.GDS.TOTL.CD  3.450887e+11  3.880226e+11  4.069728e+11
# DEU     NE.CON.TOTL.CD  1.898487e+12  1.671083e+12  1.673661e+12
#         NE.RSB.GNFS.CD  1.784117e+10  2.384277e+10  2.751362e+10
#         NY.GDS.TOTL.CD  5.987575e+11  5.409068e+11  5.653296e+11
# FRA     NE.CON.TOTL.CD  1.261993e+12  1.126496e+12  1.150978e+12
#         NE.RSB.GNFS.CD  2.861136e+10  4.377388e+10  4.127863e+10
#         NY.GDS.TOTL.CD  3.436825e+11  3.263891e+11  3.521303e+11
# GBR     NE.CON.TOTL.CD  1.147579e+12  1.275316e+12  1.360759e+12
#         NE.RSB.GNFS.CD  2.379095e+09  6.969548e+09 -1.117257e+10
#         NY.GDS.TOTL.CD  2.678112e+11  2.828864e+11  2.908596e+11
# IDN     NE.CON.TOTL.CD  1.589863e+11  1.478400e+11  7.012858e+10
#         NE.RSB.GNFS.CD -1.399778e+09 -5.941129e+08  9.306014e+09
#         NY.GDS.TOTL.CD  6.838338e+10  6.790901e+10  2.531697e+10
# IND     NE.CON.TOTL.CD  2.942253e+11  3.116536e+11  3.190415e+11
#         NE.RSB.GNFS.CD -4.554264e+09 -5.148244e+09 -7.005102e+09
#         NY.GDS.TOTL.CD  9.867174e+10  1.042141e+11  1.023099e+11
# ITA     NE.CON.TOTL.CD  9.989435e+11  9.536050e+11  9.808914e+11
#         NE.RSB.GNFS.CD  5.946166e+10  4.608709e+10  3.852281e+10
#         NY.GDS.TOTL.CD  3.134830e+11  2.882746e+11  2.891611e+11
# JPN     NE.CON.TOTL.CD  3.327989e+12  3.050631e+12  2.814131e+12
#         NE.RSB.GNFS.CD  1.859181e+10  4.420002e+10  7.149290e+10
#         NY.GDS.TOTL.CD  1.595403e+12  1.441818e+12  1.284232e+12
# KOR     NE.CON.TOTL.CD  3.883092e+11  3.624184e+11  2.365826e+11
#         NE.RSB.GNFS.CD -1.861035e+10 -4.740405e+09  4.054066e+10
#         NY.GDS.TOTL.CD  2.218604e+11  2.073361e+11  1.467483e+11
# MEX     NE.CON.TOTL.CD  3.082003e+11  3.750923e+11  3.960050e+11
#         NE.RSB.GNFS.CD  6.537922e+09 -5.579660e+08 -9.515242e+09
#         NY.GDS.TOTL.CD  1.027753e+11  1.253212e+11  1.304972e+11
# RUS     NE.CON.TOTL.CD  2.801428e+11  3.070182e+11  2.064709e+11
#         NE.RSB.GNFS.CD  1.654440e+10  8.919620e+09  1.807316e+10
#         NY.GDS.TOTL.CD  1.115821e+11  9.791080e+10  6.448460e+10
# SAU     NE.CON.TOTL.CD  1.079490e+11  1.130101e+11  1.084293e+11
#         NE.RSB.GNFS.CD  2.124780e+10  2.178959e+10  4.662133e+09
#         NY.GDS.TOTL.CD  5.071340e+10  5.295341e+10  3.834616e+10
# TUR     NE.CON.TOTL.CD  1.430829e+11  1.524305e+11  2.074781e+11
#         NE.RSB.GNFS.CD -1.140392e+10 -1.102349e+10  2.585950e+09
#         NY.GDS.TOTL.CD  3.839270e+10  3.740410e+10  6.848931e+10
# USA     NE.CON.TOTL.CD  6.417484e+12  6.757318e+12  7.144856e+12
#         NE.RSB.GNFS.CD -9.637700e+10 -1.019710e+11 -1.627110e+11
#         NY.GDS.TOTL.CD  1.655638e+12  1.820236e+12  1.917962e+12
# ZAF     NE.CON.TOTL.CD  1.206066e+11  1.260668e+11  1.136324e+11
#         NE.RSB.GNFS.CD  2.204080e+09  1.723307e+09  1.534106e+09
#         NY.GDS.TOTL.CD  2.700137e+10  2.651931e+10  2.414196e+10
#
#                               YR1999  ...        YR2010        YR2011  \
# economy series                        ...
# ARG     NE.CON.TOTL.CD  2.377779e+11  ...  3.363510e+11  4.236496e+11
#         NE.RSB.GNFS.CD -4.900400e+09  ...  1.227093e+10  8.971759e+09
#         NY.GDS.TOTL.CD  4.574508e+10  ...  8.727643e+10  1.065136e+11
# AUS     NE.CON.TOTL.CD  2.962458e+11  ...  8.501867e+11  1.012942e+12
#         NE.RSB.GNFS.CD -9.508710e+09  ... -1.180129e+10  1.349305e+10
#         NY.GDS.TOTL.CD  9.236245e+10  ...  2.959517e+11  3.837080e+11
# BRA     NE.CON.TOTL.CD  5.062604e+11  ...  1.750302e+12  2.065311e+12
#         NE.RSB.GNFS.CD -1.110289e+10  ... -2.299454e+10 -2.012853e+10
#         NY.GDS.TOTL.CD  9.312814e+10  ...  4.585692e+11  5.508895e+11
# CAN     NE.CON.TOTL.CD  5.126668e+11  ...  1.269191e+12  1.381733e+12
#         NE.RSB.GNFS.CD  2.447264e+10  ... -3.029863e+10 -2.047898e+10
#         NY.GDS.TOTL.CD  1.657454e+11  ...  3.481522e+11  4.115933e+11
# CHN     NE.CON.TOTL.CD  6.845284e+11  ...  2.977436e+12  3.787779e+12
#         NE.RSB.GNFS.CD  3.064096e+10  ...  2.223999e+11  1.808942e+11
#         NY.GDS.TOTL.CD  4.094689e+11  ...  3.109727e+12  3.763721e+12
# DEU     NE.CON.TOTL.CD  1.655394e+12  ...  2.536122e+12  2.750516e+12
#         NE.RSB.GNFS.CD  1.212551e+10  ...  1.787271e+11  1.837812e+11
#         NY.GDS.TOTL.CD  5.388099e+11  ...  8.602322e+11  9.938928e+11
# FRA     NE.CON.TOTL.CD  1.138055e+12  ...  2.096777e+12  2.252702e+12
#         NE.RSB.GNFS.CD  3.570637e+10  ... -3.412115e+10 -5.573741e+10
#         NY.GDS.TOTL.CD  3.545930e+11  ...  5.458324e+11  6.087062e+11
# GBR     NE.CON.TOTL.CD  1.400723e+12  ...  2.125572e+12  2.266253e+12
#         NE.RSB.GNFS.CD -2.411746e+10  ... -4.809022e+10 -2.537408e+10
#         NY.GDS.TOTL.CD  2.814512e+11  ...  3.560080e+11  3.936291e+11
# IDN     NE.CON.TOTL.CD  1.127686e+11  ...  4.924957e+11  5.758046e+11
#         NE.RSB.GNFS.CD  1.131819e+10  ...  1.432254e+10  2.209824e+10
#         NY.GDS.TOTL.CD  2.723271e+10  ...  2.625984e+11  3.171645e+11
# IND     NE.CON.TOTL.CD  3.495522e+11  ...  1.101423e+12  1.226761e+12
#         NE.RSB.GNFS.CD -8.770209e+09  ... -7.462085e+10 -1.192832e+11
#         NY.GDS.TOTL.CD  1.092682e+11  ...  5.741921e+11  5.962891e+11
# ITA     NE.CON.TOTL.CD  9.764057e+11  ...  1.734493e+12  1.854966e+12
#         NE.RSB.GNFS.CD  2.229469e+10  ... -3.965194e+10 -3.210152e+10
#         NY.GDS.TOTL.CD  2.756180e+11  ...  3.995247e+11  4.370254e+11
# JPN     NE.CON.TOTL.CD  3.259750e+12  ...  4.380992e+12  4.806097e+12
#         NE.RSB.GNFS.CD  6.886507e+10  ...  7.708715e+10 -4.026839e+10
#         NY.GDS.TOTL.CD  1.376232e+12  ...  1.378080e+12  1.427050e+12
# KOR     NE.CON.TOTL.CD  3.168594e+11  ...  7.395250e+11  8.217563e+11
#         NE.RSB.GNFS.CD  2.695967e+10  ...  3.212400e+10  1.390013e+10
#         NY.GDS.TOTL.CD  1.806533e+11  ...  4.045420e+11  4.314668e+11
# MEX     NE.CON.TOTL.CD  4.589095e+11  ...  8.157842e+11  9.040635e+11
#         NE.RSB.GNFS.CD -8.119178e+09  ... -1.443887e+10 -1.648275e+10
#         NY.GDS.TOTL.CD  1.413234e+11  ...  2.420171e+11  2.764261e+11
# RUS     NE.CON.TOTL.CD  1.334565e+11  ...  1.070690e+12  1.391443e+12
#         NE.RSB.GNFS.CD  3.339561e+10  ...  1.231465e+11  1.652151e+11
#         NY.GDS.TOTL.CD  6.245059e+10  ...  4.542277e+11  6.544825e+11
# SAU     NE.CON.TOTL.CD  1.083496e+11  ...  2.772239e+11  3.119528e+11
#         NE.RSB.GNFS.CD  1.857627e+10  ...  8.762827e+10  1.782472e+11
#         NY.GDS.TOTL.CD  5.336736e+10  ...  2.509834e+11  3.592860e+11
# TUR     NE.CON.TOTL.CD  2.017861e+11  ...  6.025864e+11  6.400887e+11
#         NE.RSB.GNFS.CD -1.104945e+08  ... -3.345884e+10 -6.137037e+10
#         NY.GDS.TOTL.CD  5.459938e+10  ...  1.744062e+11  1.986740e+11
# USA     NE.CON.TOTL.CD  7.635185e+12  ...  1.277130e+13  1.321017e+13
#         NE.RSB.GNFS.CD -2.595500e+11  ... -5.323080e+11 -5.796160e+11
#         NY.GDS.TOTL.CD  1.995479e+12  ...  2.220751e+12  2.332413e+12
# ZAF     NE.CON.TOTL.CD  1.120180e+11  ...  2.974577e+11  3.307568e+11
#         NE.RSB.GNFS.CD  3.454784e+09  ...  4.659892e+09  3.369875e+09
#         NY.GDS.TOTL.CD  2.461396e+10  ...  7.789169e+10  8.566211e+10
#
#                               YR2012        YR2013        YR2014  \
# economy series
# ARG     NE.CON.TOTL.CD  4.452423e+11  4.570426e+11  4.333345e+11
#         NE.RSB.GNFS.CD  1.064216e+10 -5.497189e+08  2.127192e+09
#         NY.GDS.TOTL.CD  1.007401e+11  9.498253e+10  9.298513e+10
# AUS     NE.CON.TOTL.CD  1.121054e+12  1.156923e+12  1.081271e+12
#         NE.RSB.GNFS.CD -3.845123e+09 -2.042885e+10 -6.274672e+09
#         NY.GDS.TOTL.CD  4.250980e+11  4.192613e+11  3.862132e+11
# BRA     NE.CON.TOTL.CD  1.970720e+12  1.993273e+12  2.016693e+12
#         NE.RSB.GNFS.CD -3.350622e+10 -5.691202e+10 -6.536677e+10
#         NY.GDS.TOTL.CD  4.944683e+11  4.795339e+11  4.393009e+11
# CAN     NE.CON.TOTL.CD  1.409271e+12  1.415698e+12  1.373505e+12
#         NE.RSB.GNFS.CD -3.454695e+10 -2.893983e+10 -1.635125e+10
#         NY.GDS.TOTL.CD  4.190952e+11  4.308998e+11  4.322446e+11
# CHN     NE.CON.TOTL.CD  4.363605e+12  4.949541e+12  5.502346e+12
#         NE.RSB.GNFS.CD  2.318652e+11  2.348705e+11  2.215508e+11
#         NY.GDS.TOTL.CD  4.168625e+12  4.620865e+12  4.973336e+12
# DEU     NE.CON.TOTL.CD  2.616719e+12  2.769239e+12  2.835700e+12
#         NE.RSB.GNFS.CD  2.151746e+11  2.149492e+11  2.570547e+11
#         NY.GDS.TOTL.CD  9.106255e+11  9.635042e+11  1.048220e+12
# FRA     NE.CON.TOTL.CD  2.111348e+12  2.213650e+12  2.237113e+12
#         NE.RSB.GNFS.CD -3.478250e+10 -2.908283e+10 -3.266949e+10
#         NY.GDS.TOTL.CD  5.724768e+11  5.974275e+11  6.150525e+11
# GBR     NE.CON.TOTL.CD  2.306999e+12  2.365097e+12  2.580393e+12
#         NE.RSB.GNFS.CD -3.347303e+10 -3.909261e+10 -4.760834e+10
#         NY.GDS.TOTL.CD  3.970179e+11  4.181546e+11  4.851286e+11
# IDN     NE.CON.TOTL.CD  6.024718e+11  6.054341e+11  5.929632e+11
#         NE.RSB.GNFS.CD -3.617699e+09 -7.210947e+09 -6.665133e+09
#         NY.GDS.TOTL.CD  3.153981e+11  3.070901e+11  2.978516e+11
# IND     NE.CON.TOTL.CD  1.227164e+12  1.261474e+12  1.398201e+12
#         NE.RSB.GNFS.CD -1.229061e+11 -5.537505e+10 -6.089364e+10
#         NY.GDS.TOTL.CD  6.004739e+11  5.952479e+11  6.409268e+11
# ITA     NE.CON.TOTL.CD  1.692760e+12  1.728228e+12  1.730444e+12
#         NE.RSB.GNFS.CD  2.303642e+10  5.136816e+10  6.251861e+10
#         NY.GDS.TOTL.CD  3.943173e+11  4.130876e+11  4.286904e+11
# JPN     NE.CON.TOTL.CD  4.869640e+12  4.065242e+12  3.797999e+12
#         NE.RSB.GNFS.CD -1.029522e+11 -1.256408e+11 -1.270341e+11
#         NY.GDS.TOTL.CD  1.402723e+12  1.147086e+12  1.098995e+12
# KOR     NE.CON.TOTL.CD  8.431687e+11  8.976328e+11  9.671984e+11
#         NE.RSB.GNFS.CD  3.489820e+10  6.349574e+10  7.493432e+10
#         NY.GDS.TOTL.CD  4.352590e+11  4.731624e+11  5.171198e+11
# MEX     NE.CON.TOTL.CD  9.208913e+11  1.002479e+12  1.026704e+12
#         NE.RSB.GNFS.CD -1.484680e+10 -1.470160e+10 -1.550109e+10
#         NY.GDS.TOTL.CD  2.801987e+11  2.719638e+11  2.886470e+11
# RUS     NE.CON.TOTL.CD  1.532870e+12  1.646934e+12  1.478337e+12
#         NE.RSB.GNFS.CD  1.471443e+11  1.238743e+11  1.322209e+11
#         NY.GDS.TOTL.CD  6.754259e+11  6.455393e+11  5.809053e+11
# SAU     NE.CON.TOTL.CD  3.564220e+11  3.912684e+11  4.397368e+11
#         NE.RSB.GNFS.CD  1.842137e+11  1.577431e+11  9.915838e+10
#         NY.GDS.TOTL.CD  3.795528e+11  3.553787e+11  3.166135e+11
# TUR     NE.CON.TOTL.CD  6.695415e+11  7.214196e+11  6.984658e+11
#         NE.RSB.GNFS.CD -3.618252e+10 -4.732674e+10 -3.150391e+10
#         NY.GDS.TOTL.CD  2.110148e+11  2.363634e+11  2.404869e+11
# USA     NE.CON.TOTL.CD  1.356280e+13  1.389617e+13  1.441398e+13
#         NE.RSB.GNFS.CD -5.516170e+11 -4.793940e+11 -5.100370e+11
#         NY.GDS.TOTL.CD  2.634204e+12  2.888676e+12  3.113185e+12
# ZAF     NE.CON.TOTL.CD  3.219080e+11  2.976658e+11  2.834075e+11
#         NE.RSB.GNFS.CD -5.754516e+09 -8.433692e+09 -5.253781e+09
#         NY.GDS.TOTL.CD  7.442473e+10  6.916357e+10  6.749706e+10
#
#                               YR2015        YR2016        YR2017  \
# economy series
# ARG     NE.CON.TOTL.CD  4.996145e+11  4.648500e+11  5.434573e+11
#         NE.RSB.GNFS.CD -6.393091e+09 -5.796640e+09 -1.704994e+10
#         NY.GDS.TOTL.CD  9.513480e+10  9.268140e+10  1.001714e+11
# AUS     NE.CON.TOTL.CD  1.017204e+12  9.296455e+11  1.001548e+12
#         NE.RSB.GNFS.CD -2.060904e+10 -2.750764e+10  7.879176e+09
#         NY.GDS.TOTL.CD  3.344904e+11  2.792015e+11  3.276408e+11
# BRA     NE.CON.TOTL.CD  1.509203e+12  1.519715e+12  1.746888e+12
#         NE.RSB.GNFS.CD -2.078421e+10  7.176696e+09  1.482014e+10
#         NY.GDS.TOTL.CD  2.930109e+11  2.759852e+11  3.166203e+11
# CAN     NE.CON.TOTL.CD  1.224767e+12  1.215250e+12  1.297635e+12
#         NE.RSB.GNFS.CD -3.836763e+10 -3.603836e+10 -3.615587e+10
#         NY.GDS.TOTL.CD  3.317419e+11  3.127446e+11  3.516306e+11
# CHN     NE.CON.TOTL.CD  5.972231e+12  6.182654e+12  6.754427e+12
#         NE.RSB.GNFS.CD  3.588357e+11  2.554835e+11  2.156957e+11
#         NY.GDS.TOTL.CD  5.089322e+12  5.050623e+12  5.555982e+12
# DEU     NE.CON.TOTL.CD  2.438701e+12  2.519335e+12  2.648964e+12
#         NE.RSB.GNFS.CD  2.549146e+11  2.557932e+11  2.609935e+11
#         NY.GDS.TOTL.CD  9.175343e+11  9.481634e+11  1.032768e+12
# FRA     NE.CON.TOTL.CD  1.898245e+12  1.927496e+12  2.009598e+12
#         NE.RSB.GNFS.CD -1.381121e+10 -1.495296e+10 -2.755924e+10
#         NY.GDS.TOTL.CD  5.399625e+11  5.437897e+11  5.791430e+11
# GBR     NE.CON.TOTL.CD  2.456813e+12  2.261489e+12  2.215797e+12
#         NE.RSB.GNFS.CD -4.319333e+10 -4.875955e+10 -3.846705e+10
#         NY.GDS.TOTL.CD  4.759715e+11  4.317582e+11  4.466871e+11
# IDN     NE.CON.TOTL.CD  5.784892e+11  6.276624e+11  6.743317e+11
#         NE.RSB.GNFS.CD  3.294647e+09  7.051012e+09  1.014717e+10
#         NY.GDS.TOTL.CD  2.823651e+11  3.042150e+11  3.412871e+11
# IND     NE.CON.TOTL.CD  1.460638e+12  1.597267e+12  1.842571e+12
#         NE.RSB.GNFS.CD -4.830964e+10 -4.052650e+10 -8.375916e+10
#         NY.GDS.TOTL.CD  6.429496e+11  6.975307e+11  8.089021e+11
# ITA     NE.CON.TOTL.CD  1.466497e+12  1.484709e+12  1.547608e+12
#         NE.RSB.GNFS.CD  5.533012e+10  6.167957e+10  5.603318e+10
#         NY.GDS.TOTL.CD  3.694022e+11  3.910889e+11  4.093423e+11
# JPN     NE.CON.TOTL.CD  3.350968e+12  3.720671e+12  3.650077e+12
#         NE.RSB.GNFS.CD -2.461997e+10  4.031421e+10  3.745783e+10
#         NY.GDS.TOTL.CD  1.093962e+12  1.283007e+12  1.280760e+12
# KOR     NE.CON.TOTL.CD  9.325848e+11  9.480079e+11  1.022481e+12
#         NE.RSB.GNFS.CD  1.003561e+11  9.992982e+10  7.709466e+10
#         NY.GDS.TOTL.CD  5.331884e+11  5.521037e+11  6.014209e+11
# MEX     NE.CON.TOTL.CD  9.108830e+11  8.361822e+11  8.904587e+11
#         NE.RSB.GNFS.CD -2.389811e+10 -2.133111e+10 -2.100655e+10
#         NY.GDS.TOTL.CD  2.609846e+11  2.423084e+11  2.684544e+11
# RUS     NE.CON.TOTL.CD  9.605072e+11  9.156316e+11  1.119067e+12
#         NE.RSB.GNFS.CD  1.097252e+11  6.627605e+10  8.351502e+10
#         NY.GDS.TOTL.CD  4.029739e+11  3.611554e+11  4.551324e+11
# SAU     NE.CON.TOTL.CD  4.599856e+11  4.426903e+11  4.518993e+11
#         NE.RSB.GNFS.CD -2.929686e+10  2.749855e+09  3.801764e+10
#         NY.GDS.TOTL.CD  1.942843e+11  2.022452e+11  2.366870e+11
# TUR     NE.CON.TOTL.CD  6.380972e+11  6.448040e+11  6.269737e+11
#         NE.RSB.GNFS.CD -1.751096e+10 -1.879553e+10 -3.163962e+10
#         NY.GDS.TOTL.CD  2.262194e+11  2.248890e+11  2.320226e+11
# USA     NE.CON.TOTL.CD  1.487246e+13  1.535637e+13  1.596980e+13
#         NE.RSB.GNFS.CD -5.261990e+11 -5.062490e+11 -5.399330e+11
#         NY.GDS.TOTL.CD  3.365842e+12  3.388702e+12  3.573178e+12
# ZAF     NE.CON.TOTL.CD  2.547717e+11  2.373210e+11  2.797616e+11
#         NE.RSB.GNFS.CD -4.164948e+09  1.551928e+09  4.479340e+09
#         NY.GDS.TOTL.CD  6.284878e+10  5.903629e+10  6.979253e+10
#
#                               YR2018        YR2019
# economy series
# ARG     NE.CON.TOTL.CD  4.256230e+11  3.580720e+11
#         NE.RSB.GNFS.CD -1.001752e+10  1.003037e+10
#         NY.GDS.TOTL.CD  9.200369e+10  8.737315e+10
# AUS     NE.CON.TOTL.CD  1.075951e+12  1.037533e+12
#         NE.RSB.GNFS.CD  5.461592e+09  3.507438e+10
#         NY.GDS.TOTL.CD  3.569297e+11  3.590345e+11
# BRA     NE.CON.TOTL.CD  1.620034e+12  1.593176e+12
#         NE.RSB.GNFS.CD  7.548853e+09 -4.604637e+09
#         NY.GDS.TOTL.CD  2.969128e+11  2.846347e+11
# CAN     NE.CON.TOTL.CD  1.354515e+12  1.368888e+12
#         NE.RSB.GNFS.CD -3.256303e+10 -2.779031e+10
#         NY.GDS.TOTL.CD  3.673384e+11  3.726880e+11
# CHN     NE.CON.TOTL.CD  7.650165e+12  7.999417e+12
#         NE.RSB.GNFS.CD  1.067071e+11  1.649864e+11
#         NY.GDS.TOTL.CD  6.244652e+12  6.280520e+12
# DEU     NE.CON.TOTL.CD  2.859374e+12  2.807763e+12
#         NE.RSB.GNFS.CD  2.451869e+11  2.196443e+11
#         NY.GDS.TOTL.CD  1.115973e+12  1.080564e+12
# FRA     NE.CON.TOTL.CD  2.152266e+12  2.090116e+12
#         NE.RSB.GNFS.CD -2.819214e+10 -2.612518e+10
#         NY.GDS.TOTL.CD  6.373285e+11  6.387542e+11
# GBR     NE.CON.TOTL.CD  2.380144e+12  2.352942e+12
#         NE.RSB.GNFS.CD -3.400163e+10 -3.506308e+10
#         NY.GDS.TOTL.CD  4.771728e+11  4.778714e+11
# IDN     NE.CON.TOTL.CD  6.879110e+11  7.468880e+11
#         NE.RSB.GNFS.CD -1.113996e+10 -6.224073e+09
#         NY.GDS.TOTL.CD  3.543606e+11  3.722033e+11
# IND     NE.CON.TOTL.CD  1.896331e+12  2.058484e+12
#         NE.RSB.GNFS.CD -1.003781e+11 -7.256629e+10
#         NY.GDS.TOTL.CD  8.047803e+11  8.120200e+11
# ITA     NE.CON.TOTL.CD  1.653409e+12  1.577986e+12
#         NE.RSB.GNFS.CD  5.025624e+10  6.583148e+10
#         NY.GDS.TOTL.CD  4.377085e+11  4.269275e+11
# JPN     NE.CON.TOTL.CD  3.748650e+12  3.824312e+12
#         NE.RSB.GNFS.CD  1.006129e+09 -1.602610e+09
#         NY.GDS.TOTL.CD  1.288241e+12  1.324470e+12
# KOR     NE.CON.TOTL.CD  1.105197e+12  1.082041e+12
#         NE.RSB.GNFS.CD  7.654375e+10  4.772081e+10
#         NY.GDS.TOTL.CD  6.196491e+11  5.646978e+11
# MEX     NE.CON.TOTL.CD  9.330434e+11  9.674015e+11
#         NE.RSB.GNFS.CD -2.498942e+10 -3.180370e+09
#         NY.GDS.TOTL.CD  2.893054e+11  3.014691e+11
# RUS     NE.CON.TOTL.CD  1.128249e+12  1.173384e+12
#         NE.RSB.GNFS.CD  1.658260e+11  1.287256e+11
#         NY.GDS.TOTL.CD  5.290802e+11  5.140642e+11
# SAU     NE.CON.TOTL.CD  4.918243e+11  4.978639e+11
#         NE.RSB.GNFS.CD  1.053272e+11  6.691908e+10
#         NY.GDS.TOTL.CD  2.946975e+11  2.951029e+11
# TUR     NE.CON.TOTL.CD  5.515197e+11  5.512792e+11
#         NE.RSB.GNFS.CD -1.071676e+09  2.131957e+10
#         NY.GDS.TOTL.CD  2.268573e+11  2.101490e+11
# USA     NE.CON.TOTL.CD  1.678295e+13  1.740259e+13
#         NE.RSB.GNFS.CD -5.961860e+11 -5.962630e+11
#         NY.GDS.TOTL.CD  3.828913e+12  4.030631e+12
# ZAF     NE.CON.TOTL.CD  2.991007e+11  2.865325e+11
#         NE.RSB.GNFS.CD  1.266293e+09  1.768202e+09
#         NY.GDS.TOTL.CD  6.918822e+10  6.489912e+10
#
# [57 rows x 30 columns]

# %%
df_outputs_economia[df_outputs_economia.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [YR1990, YR1991, YR1992, YR1993, YR1994, YR1995, YR1996, YR1997, YR1998, YR1999, YR2000, YR2001, YR2002, YR2003, YR2004, YR2005, YR2006, YR2007, YR2008, YR2009, YR2010, YR2011, YR2012, YR2013, YR2014, YR2015, YR2016, YR2017, YR2018, YR2019]
# Index: []
#
# [0 rows x 30 columns]

# %%
df_outputs_economia.fillna(df_outputs_economia.mean(), inplace=True)
# df_outputs_economia=df_outputs_economia.groupby(level=0).sum()

# %%
# df_outputs_economia.transpose().
x = df_outputs_economia.values
y = df_outputs_economia.values

# %%
y.shape
# Out:
# (19, 30)

# %% [markdown]
# ## MODELOS

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
from sklearn.metrics import mean_squared_error as mse
from yellowbrick.regressor import residuals_plot,ResidualsPlot
from yellowbrick.regressor import prediction_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.multioutput import MultiOutputRegressor
import pickle

# %%
sc = MinMaxScaler(feature_range = (-1, 1))

# %%
# sc = MinMaxScaler(feature_range = (-100, 100))

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, 
                                                    random_state=42)

# %%
y_train.shape
# Out:
# (51, 30)

# %%
xgb_reg = MultiOutputRegressor(XGBRegressor(max_depth=3, n_estimators=100, n_jobs=3,
                           objective='reg:squarederror',
                           random_state=42, learning_rate=0.05))

# %%
xgb_reg.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             enable_categorical=False,
#                                             gamma=None, gpu_id=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=0.05,
#                                             max_delta_step=None, max_depth=3,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=3,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=42,
#                                             reg_alpha=None, reg_lambda=None,
#                                             scale_pos_weight=None,
#                                             subsample=None, tree_method=None,
#                                             validate_parameters=None,
#                                             verbosity=None))

# %%
y_pred = xgb_reg.predict(X_test) # Predictions
y_true = y_test # True values

# %%
MSE = mse(y_true, y_pred)
RMSE = np.sqrt(MSE)

# %%
R_squared = r2_score(y_true, y_pred)

# %%
print("\nRMSE: ", np.round(RMSE, 2))
print()
print("R-Squared: ", np.round(R_squared, 2))
# Out:
# RMSE:  0.02
#
# R-Squared:  0.92

# %%
# Making the Prediction Error Plot
print("\nPrediction Error Plot")
print(prediction_error(xgb_reg, X_train, y_train, X_test, y_test))
# Out:
# Prediction Error Plot
# ---------------------------------------------------------------------------
# YellowbrickValueError                     Traceback (most recent call last)
# /tmp/ipykernel_46101/3824074451.py in <module>
#       1 # Making the Prediction Error Plot
#       2 print("\nPrediction Error Plot")
# ----> 3 print(prediction_error(xgb_reg, X_train, y_train, X_test, y_test))
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/prediction_error.py in prediction_error(estimator, X_train, y_train, X_test, y_test, ax, shared_limits, bestfit, identity, alpha, is_fitted, show, **kwargs)
#     383     # Scores the visualizer with X and y test if provided, X and y train if not
#     384     if X_test is not None and y_test is not None:
# --> 385         visualizer.score(X_test, y_test)
#     386     elif X_test is not None or y_test is not None:
#     387         raise YellowbrickValueError(
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/prediction_error.py in score(self, X, y, **kwargs)
#     164
#     165         y_pred = self.predict(X)
# --> 166         self.draw(y, y_pred)
#     167
#     168         return self.score_
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/prediction_error.py in draw(self, y, y_pred)
#     191         # Ideally we'd want the best fit line to be drawn only once
#     192         if self.bestfit:
# --> 193             draw_best_fit(
#     194                 y,
#     195                 y_pred,
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/bestfit.py in draw_best_fit(X, y, ax, estimator, **kwargs)
#     139     # Verify that y is a (n,) dimensional array
#     140     if y.ndim > 1:
# --> 141         raise YellowbrickValueError(
#     142             "y must be a (1,) dimensional array not {}".format(y.shape)
#     143         )
#
# YellowbrickValueError: y must be a (1,) dimensional array not (6, 30)

# %%
# Making the Residuals Plot
print("\nResiduals Plot")
print(residuals_plot(xgb_reg, X_train, y_train, X_test, y_test))
# Out:
# Residuals Plot
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_46101/1364616012.py in <module>
#       1 # Making the Residuals Plot
#       2 print("\nResiduals Plot")
# ----> 3 print(residuals_plot(xgb_reg, X_train, y_train, X_test, y_test))
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/residuals.py in residuals_plot(estimator, X_train, y_train, X_test, y_test, ax, hist, qqplot, train_color, test_color, line_color, train_alpha, test_alpha, is_fitted, show, **kwargs)
#     533
#     534     # Fit the visualizer
# --> 535     viz.fit(X_train, y_train)
#     536
#     537     # Score the visualizer
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/residuals.py in fit(self, X, y, **kwargs)
#     260         # fit the underlying model to the data
#     261         super(ResidualsPlot, self).fit(X, y, **kwargs)
# --> 262         self.score(X, y, train=True)
#     263         return self
#     264
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/residuals.py in score(self, X, y, train, **kwargs)
#     296         y_pred = self.predict(X)
#     297         residuals = y_pred - y
# --> 298         self.draw(y_pred, residuals, train=train)
#     299
#     300         return score
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/yellowbrick/regressor/residuals.py in draw(self, y_pred, residuals, train, **kwargs)
#     345         # Add residuals histogram
#     346         if self.hist in {True, "frequency"}:
# --> 347             self.hax.hist(residuals, bins=50, orientation="horizontal", color=color)
#     348         elif self.hist == "density":
#     349             self.hax.hist(
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Projects/jogo_economia_sensata/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6713             color = mcolors.to_rgba_array(color)
#    6714             if len(color) != nx:
# -> 6715                 raise ValueError(f"The 'color' keyword argument must have one "
#    6716                                  f"color per dataset, but {nx} datasets and "
#    6717                                  f"{len(color)} colors were provided")
#
# ValueError: The 'color' keyword argument must have one color per dataset, but 30 datasets and 1 colors were provided

# %%
with open('model_economia.pkl','wb') as f:
    pickle.dump(xgb_reg,f)
